# %%
# %matplotlib inline
from datascience import * 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
matplotlib.style.use('ggplot')

# %%
dataframe = pd.read_csv("CoolTerm Capture 2018-02-03 15-58-21.txt")

# %%
ax= dataframe.plot.line()
plt.show()
